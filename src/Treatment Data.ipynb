# %%
import pandas as pd
import numpy as np
import ODElib
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("../data/treatmentsedited.csv")

# %%
data
# Out:
#           treatments Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4 Unnamed: 5  \
# 0                 id   organism    control       time    abundance   logscale
# 1     Steenhauer2016          V      FALSE   9.85E-03  7504123.969       TRUE
# 2     Steenhauer2016          V      FALSE    16.0339  4993441.887       TRUE
# 3     Steenhauer2016          V      FALSE    19.9987  5140436.516       TRUE
# 4     Steenhauer2016          V      FALSE    24.0796  13283117.06       TRUE
# ...              ...        ...        ...        ...          ...        ...
# 1816          Maat4D          V      FALSE    24.0251     67726000      FALSE
# 1817          Maat4D          V      FALSE    29.9998     74348000      FALSE
# 1818          Maat4D          V      FALSE    36.0152     89097000      FALSE
# 1819          Maat4D          V      FALSE    48.0031    102240000      FALSE
# 1820          Maat4D          V      FALSE    72.0153    119700000      FALSE
#
# ...
